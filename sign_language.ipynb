# %%
# !nvidia-smi
# Out:
# Sun Feb  2 13:31:59 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="cXNomVcokXUrbTAIMmG9")
project = rf.workspace("arijit-goswami-ksn6e").project("sign-recoginition-i1exh")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Sign-recoginition-2 in yolov8:: 100%|██████████| 4256/4256 [00:00<00:00, 10730.25it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 25.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/Sign-recoginition-2/data.yaml epochs=30 imgsz=640 batch=16
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 111MB/s]
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt source=/content/Sign-recoginition-2/valid/images save=True
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 3,014,618 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/414 /content/Sign-recoginition-2/valid/images/001_jpg.rf.2f761ce292ae71310e4ba11cc81e4840.jpg: 480x640 1 O, 36.0ms
# image 2/414 /content/Sign-recoginition-2/valid/images/002_jpg.rf.e393cfab024606ea0172371605891dec.jpg: 480x640 1 O, 7.0ms
# image 3/414 /content/Sign-recoginition-2/valid/images/003_jpg.rf.e257c658dad921997c4b9d94f3a956cb.jpg: 480x640 1 C, 6.1ms
# image 4/414 /content/Sign-recoginition-2/valid/images/009_jpg.rf.d7fae74087ed749c9282a36e37576be3.jpg: 384x640 1 V, 35.1ms
# image 5/414 /content/Sign-recoginition-2/valid/images/010_jpg.rf.dd1336a95f1e9144ceb047ab40215249.jpg: 480x640 1 C, 6.6ms
# image 6/414 /content/Sign-recoginition-2/valid/images/012_jpg.rf.cb95cb95b03637415ef0502c0e2c9b33.jpg: 480x640 1 O, 6.0ms
# ...

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %%
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/sign_recognitionl.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip sign_recognition.pt
# !zip -r /content/my_model.zip train
# %cd /content
# Out:
# /content/my_model
# 	zip warning: name not matched: sign_recognition.pt
#
# zip error: Nothing to do! (/content/my_model.zip)
#   adding: train/ (stored 0%)
#   adding: train/results.png (deflated 8%)
#   adding: train/confusion_matrix.png (deflated 24%)
#   adding: train/F1_curve.png (deflated 11%)
#   adding: train/val_batch0_pred.jpg (deflated 19%)
#   adding: train/train_batch1.jpg (deflated 8%)
#   adding: train/results.csv (deflated 59%)
#   adding: train/events.out.tfevents.1738503453.2ac0752ed741.2260.0 (deflated 91%)
#   adding: train/labels.jpg (deflated 37%)
#   adding: train/val_batch2_pred.jpg (deflated 18%)
#   adding: train/P_curve.png (deflated 16%)
#   adding: train/train_batch1860.jpg (deflated 13%)
#   adding: train/confusion_matrix_normalized.png (deflated 24%)
#   adding: train/train_batch0.jpg (deflated 9%)
#   adding: train/val_batch0_labels.jpg (deflated 19%)
#   adding: train/val_batch2_labels.jpg (deflated 18%)
#   adding: train/args.yaml (deflated 53%)
# ...
